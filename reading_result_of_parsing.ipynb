# %%
import pandas as pd

# %%
pd.read_csv('cian.csv', sep='\t')
# Out:
#     Number_of_rooms                   housing_complex  total_area  \
# 0                 1                               NaN       36.40
# 1                 1                ЦДС Кантемировский       40.82
# 2                 1                  Дом на Обручевых       43.00
# 3                 2                ЦДС Кантемировский       55.78
# 4                 1                         Три ветра       49.00
# 5                 1               Кристалл Полюстрово       48.80
# 6                 2                               NaN       57.98
# 7                 2                               NaN       49.30
# 8                 1                               NaN       45.10
# 9                 2                               NaN       65.30
# 10                1                               NaN       38.30
# 11                1                               NaN       34.40
# 12                2                               NaN       46.60
# ...
