# %%
import pandas as pd

# %%
pd.read_csv('cian.csv', sep='\t')
# Out:
#     Number of rooms                   housing_complex  total_area  \
# 0                 1                        Green City       35.70
# 1                 2  Петр Великий и Екатерина Великая       59.09
# 2                 2                               NaN       55.70
# 3                 2                               NaN       44.00
# 4                 1                 Дом на набережной       44.00
# 5                 1                 Дом на набережной       40.70
# 6                 2                      Дом у ратуши       81.30
# 7                 1                               NaN       34.40
# 8                 1                               NaN       45.10
# 9                 2                               NaN       46.60
# 10                2                               NaN       57.98
# 11                2                          Граффити       57.45
# 12                2                               NaN       58.80
# ...
