# %%
import pandas as pd

# %%
pd.read_csv('cian.csv', sep='\t')
# Out:
#     Number_of_rooms      housing_complex  total_area  living_area  \
# 0                 1                  NaN       36.40         17.2
# 1                 1   ЦДС Кантемировский       40.82         15.8
# 2                 1     Дом на Обручевых       43.00         18.6
# 3                 2   ЦДС Кантемировский       55.78         31.5
# 4                 1            Три ветра       49.00         17.8
# 5                 1  Кристалл Полюстрово       48.80         16.8
# 6                 2                  NaN       57.98         28.1
# 7                 1                  NaN       34.40         17.2
# 8                 1                  NaN       38.30         20.0
# 9                 1                  NaN       45.10         17.0
# 10                2                  NaN       46.60         28.8
# 11                2                  NaN       49.30         29.8
# 12                2                  NaN       65.30         33.0
#
# ...
